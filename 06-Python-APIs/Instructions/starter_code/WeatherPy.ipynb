# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import csv
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from collections import OrderedDict

# Import API key
api_keys = "f58baf990560885b1bf3cf7d56909077"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_weather = [] #where the weather data will be stored
units = "metric"
api_key = "f58baf990560885b1bf3cf7d56909077"
url = "http://api.openweathermap.org/data/2.5/weather?"

for city in cities:
    query_url = f"{url}appid={api_key}&q={city}&units={units}"
    print(f"Retreiving data for: {city}")
    # Get weather data
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    city_weather.append(weather_json)
# Out:
# Retreiving data for: hermanus
# Retreiving data for: upernavik
# Retreiving data for: rikitea
# Retreiving data for: mataura
# Retreiving data for: maraba
# Retreiving data for: nikolskoye
# Retreiving data for: haines junction
# Retreiving data for: vaini
# Retreiving data for: mar del plata
# Retreiving data for: cape town
# Retreiving data for: cairns
# Retreiving data for: jamestown
# Retreiving data for: east london
# Retreiving data for: saint-philippe
# Retreiving data for: santa eulalia
# Retreiving data for: laurel
# Retreiving data for: port alfred
# Retreiving data for: bengkulu
# Retreiving data for: ponta do sol
# Retreiving data for: bluff
# Retreiving data for: avarua
# Retreiving data for: koshurnikovo
# Retreiving data for: ushuaia
# Retreiving data for: baykit
# Retreiving data for: nanortalik
# Retreiving data for: kudahuvadhoo
# Retreiving data for: jalu
# Retreiving data for: saint george
# Retreiving data for: nkhata bay
# Retreiving data for: margate
# ...

# %%
names = []
temps = []
humidity = []
cloudiness = []
wind = []
city_lats = []
city_long = []
counrty = []

for city in city_weather:
    try:
        names.append(city['name'])
        temps.append(city['main']['temp'])
        humidity.append(city['main']['humidity'])
        cloudiness.append(city['clouds']['all'])
        wind.append(city['wind']['speed'])
        city_lats.append(city['coord']['lat'])
        city_long.append(city['coord']['lon'])
        country.append(city['sys']['country'])
    except:
        next

# %%
data = []
weather_df = pd.DataFrame(data, columns=['City Name', 'Temperature', 'Humidity', 'Cloudiness','Wind Speed'])

# %%
weather_df['City Name'] = names
weather_df['Temperature'] = temps
weather_df['Humidity'] = humidity
weather_df['Cloudiness'] = cloudiness
weather_df['Wind Speed'] = wind
weather_df['Lats'] = city_lats
weather_df['Long'] = city_long

# %%
lat_list = weather_df['Lats'].tolist()
temp_list = weather_df['Temperature'].tolist()
cloudy_list = weather_df['Cloudiness'].tolist()
wind_list = weather_df['Wind Speed'].tolist()
humidity = weather_df['Humidity'].tolist()

# %%
weather_df.to_csv()
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lat_list, temp_list, alpha=.5, edgecolors=None)
plt.grid(True)
plt.title('City Latitude vs. Max Temperature 8/31/2019')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat_list, temp_list, alpha=.5, edgecolors=None)
plt.grid(True)
plt.title('City Latitude vs. Max Temperature 8/31/2019')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
# Out:
# Text(0, 0.5, 'Max Temperature (F)')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat_list, cloudy_list, alpha=.5, edgecolors=None)
plt.grid(True)
plt.title('City Latitude vs. Cloudiness 8/31/2019')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
# Out:
# Text(0, 0.5, 'Cloudiness (%)')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat_list, wind_list, alpha=.5, edgecolors=None)
plt.grid(True)
plt.title('City Latitude vs. Wind Speed 8/31/2019')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
# Out:
# Text(0, 0.5, 'Wind Speed (mph)')
